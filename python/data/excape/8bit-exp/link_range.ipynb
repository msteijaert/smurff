# %%
import matrix_io as mio

beta = mio.read_matrix("macau-c2v-8bit/sv-sample-800-F0-link.ddm")
U0 = mio.read_matrix("macau-c2v-8bit/sv-sample-800-U0-latents.ddm")

# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import numpy as np

beta_flat = beta.flatten()
#beta_flat = (beta.flatten() - beta.min()) / (beta.max() - beta.min())
#plt.hist(Fflat, range =(-1000,2000), bins = 1000, log = True)
plt.hist(beta_flat, bins=1000, log =True)

plt.title("Histogram beta")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
U0_flat = U0.flatten()
plt.hist(U0_flat, bins=1000, log =True, range = (-10,10))

plt.title("Histogram U")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
